# %%
import csv
import json
import pandas as pd

# %%
ccrb = pd.read_csv('data/ccrb_master.csv', header=0, low_memory=False)

ccrb.head()
# Out:
#         id Officer.last.name Officer.first.name Current.command  \
# 0  30778.0            WRIGHT             CURTIS         114 PCT
# 1  30778.0            WRIGHT             CURTIS         114 PCT
# 2  30778.0            WRIGHT             CURTIS         114 PCT
# 3  56079.0            RHODEN               KYLE         MED DIV
# 4  56079.0            RHODEN               KYLE         MED DIV
#
#      Current.rank  Current.badge  Complaint.ID Report    year  month  day  \
# 0  Police Officer         4439.0   200000003.0    NaN  2000.0    1.0  1.0
# 1  Police Officer         4439.0   200000003.0    NaN  2000.0    1.0  1.0
# 2  Police Officer         4439.0   200000003.0    NaN  2000.0    1.0  1.0
# 3  Police Officer        10384.0   200000003.0    NaN  2000.0    1.0  1.0
# 4  Police Officer        10384.0   200000003.0    NaN  2000.0    1.0  1.0
#
#              category                             Allegation  \
# 0  Abuse of Authority                    Frisk and/or search
# ...

# %%
counts = pd.read_csv('data/counts/complaint_counts.csv', header=0, low_memory=False).fillna(0)

counts=counts.drop(['na'], axis=1)
counts.head()

counts.to_csv(input(), index=False)
# Out:
# complaint_counts.csv

# %%
ccrb = ccrb[ccrb['year']>=2010]
#recent.head()

count_complaints = []
year = list(range(2010,2023))

ccrb.head()
# Out:
#             id Officer.last.name Officer.first.name Current.command  \
# 94395  69503.0               GAO                XUE           PSA 1
# 94396  37442.0            RIVERA           FRANKLIN           CO TR
# 94397  49703.0             VILLA            MICHAEL          HWY 03
# 94398  49703.0             VILLA            MICHAEL          HWY 03
# 94399  49703.0             VILLA            MICHAEL          HWY 03
#
#          Current.rank  Current.badge  Complaint.ID Report    year  month  \
# 94395      Lieutenant            0.0   201000008.0    NaN  2010.0    1.0
# 94396  Police Officer        23506.0   201000009.0    NaN  2010.0    1.0
# 94397  Police Officer         7518.0   201000009.0    NaN  2010.0    1.0
# 94398  Police Officer         7518.0   201000009.0    NaN  2010.0    1.0
# 94399  Police Officer         7518.0   201000009.0    NaN  2010.0    1.0
#
#         day            category          Allegation  \
# 94395   3.0  Abuse of Authority    Threat of arrest
# ...

# %%
year
# Out:
# [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]

# %%
print(year)
# Out:
# [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]

# %%
# Out:
# range(2000, 2002)

# %%
payroll = pd.read_csv('figs/data/payroll.csv', header=0, low_memory=False).fillna(0)


payroll.head()
# Out:
#    Fiscal.year                    Agency          First.name Borough  \
# 0         2021  DEPARTMENT OF CORRECTION  SHELLON, AARON, NA  QUEENS
# 1         2021  DEPARTMENT OF CORRECTION  IBRAHIM, AAYAN, NA  QUEENS
# 2         2021  DEPARTMENT OF CORRECTION      DAISY, ABAD, J  QUEENS
# 3         2021  DEPARTMENT OF CORRECTION   JUSTIN, ABASI, NA  QUEENS
# 4         2021  DEPARTMENT OF CORRECTION    JUAN, ABBATE, NA  QUEENS
#
#                 Title Leave.status  Base.salary  Pay.basis  Reg.hours  \
# 0  CORRECTION OFFICER       ACTIVE        92073  per Annum     2000.0
# 1  CORRECTION OFFICER       ACTIVE        67196  per Annum     2080.0
# 2  CORRECTION OFFICER       ACTIVE        52216  per Annum     2080.0
# 3  CORRECTION OFFICER       ACTIVE        62166  per Annum     2080.0
# 4  CORRECTION OFFICER       ACTIVE        92073  per Annum     2080.0
#
#    Regular.gross.paid  Overtime.hours  Total.overtime.paid  Total.other.pay
# ...

# %%
borough = payroll['Borough']
links = []

for i in borough:
    if (i=="QUEENS"):
        links.append("{source: i, target: 1, weight: 5}")
    
    if (i=="BROOKLYN"):
        links.append("{source: i, target: 2, weight: 5}")
        
    if (i=="MANHATTAN"):
        links.append("{source: i, target: 3, weight: 5}")
        
    if (i=="BRONX"):
        links.append("{source: i, target: 4, weight: 5}")
        
    if (i=="RICHMOND"):
        links.append("{source: i, target: 5, weight: 5}")

        print(links)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
print(links)
# Out:
# ['{source: i, target: 1, weight: 5}', '{source: i, target: 1, weight: 5}', '{source: i, target: 1, weight: 5}', '{source: i, target: 1, weight: 5}', '{source: i, target: 1, weight: 5}', '{source: i, target: 1, weight: 5}', '{source: i, target: 1, weight: 5}', '{source: i, target: 1, weight: 5}', '{source: i, target: 1, weight: 5}', '{source: i, target: 1, weight: 5}', '{source: i, target: 1, weight: 5}', '{source: i, target: 1, weight: 5}', '{source: i, target: 1, weight: 5}', '{source: i, target: 3, weight: 5}', '{source: i, target: 1, weight: 5}', '{source: i, target: 1, weight: 5}', '{source: i, target: 1, weight: 5}', '{source: i, target: 1, weight: 5}', '{source: i, target: 1, weight: 5}', '{source: i, target: 1, weight: 5}', '{source: i, target: 1, weight: 5}', '{source: i, target: 1, weight: 5}', '{source: i, target: 3, weight: 5}', '{source: i, target: 1, weight: 5}', '{source: i, target: 4, weight: 5}', '{source: i, target: 1, weight: 5}', '{source: i, target: 2, weight: 5}'
# ...
